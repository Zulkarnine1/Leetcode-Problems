# %% [markdown]
# ![image.png](attachment:image.png)

# %%
class Solution:
    def lengthOfLastWord(self, s: str) -> int:
        s_arr = s.split(" ")
        length = 0
        
        for i in range(len(s_arr)-1,-1,-1):
            temp = len(s_arr[i])
            if(temp>0):
                length = temp
                break
        return length
